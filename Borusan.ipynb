# %%
pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 75.7 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0

# %% [markdown]
# # Loading Data

# %%
import pandas as pd

# Assuming the file is named 'population.xlsx'
population = pd.read_excel('population.xlsx')
# Modify the "Belediyeler" column to extract only the first word
population['Belediyeler'] = population['Belediyeler'].apply(lambda x: x.split()[0])
# Display the first few rows of the modified dataset
population.head()
# Out:
#   Belediyeler  2019 yılı nüfusları
# 0      Adalar                15238
# 1  Arnavutköy               282488
# 2    Ataşehir               425094
# 3     Avcılar               448882
# 4    Bağcılar               745125

# %%
# prompt: Using dataframe population: create the sum of second column using pivot method or a basic method

# Calculate the sum of the "2019 yılı nüfuslar" column
total_population = population["2019 yılı nüfusları"].sum()

# Print the result
print(f"Total population in 2019: {total_population}")
print("Number of districts:",population.Belediyeler.nunique())
# Out:
# Total population in 2019: 15519267
# Number of districts: 39

# %%
import json
import pandas as pd

# Open the JSON file with 'utf-8-sig' encoding to handle BOM
with open('turkey-geo.json', 'r', encoding='utf-8-sig') as file:
    data = json.load(file)

# If the JSON has a 'features' key or similar, extract the relevant part (adjust based on your file structure)
if isinstance(data, dict) and 'features' in data:
    data = data['features']

# Convert the JSON data to a DataFrame
df = pd.DataFrame(data)

# Function to split the "Coordinates" field into Latitude and Longitude for the province
def split_coordinates(coordinates):
    try:
        lat, lon = map(float, coordinates.split(', '))
        return pd.Series([lat, lon])
    except:
        return pd.Series([None, None])

# Apply the function to the 'Coordinates' column to extract latitude and longitude
df[['Province_Latitude', 'Province_Longitude']] = df['Coordinates'].apply(split_coordinates)

# Define a function to extract district names and coordinates (and split them into Latitude and Longitude)
def extract_district_info(districts):
    if isinstance(districts, list):
        return [(district['District'], *map(float, district['Coordinates'].split(', '))) for district in districts]
    return None

# Apply the function to the 'Districts' column to extract district names and their coordinates
df['District_Info'] = df['Districts'].apply(extract_district_info)

# Explode the 'District_Info' column into separate rows (if there are multiple districts)
df_exploded = df.explode('District_Info')

# Split 'District_Info' into District name, Latitude, and Longitude
df_exploded[['District', 'District_Latitude', 'District_Longitude']] = pd.DataFrame(df_exploded['District_Info'].tolist(), index=df_exploded.index)

# Drop the original 'Districts', 'Coordinates', and 'District_Info' columns as they are no longer needed
df_exploded.drop(columns=['Districts', 'Coordinates', 'District_Info'], inplace=True)

# Display the resulting DataFrame
df_exploded.head(2)
# Out:
#   Province  PlateNumber  Province_Latitude  Province_Longitude District  \
# 0    Adana            1               37.0              35.325   Aladağ
# 0    Adana            1               37.0              35.325   Ceyhan
#
#    District_Latitude  District_Longitude
# 0            37.5485             35.3960
# 0            37.0247             35.8175

# %%
istanbul_df = df_exploded[df_exploded['Province'] == 'İstanbul']
istanbul_df.head()
print("Number of districts:",istanbul_df.District.nunique())
# Out:
# Number of districts: 39

# %%
# prompt: I want you to join df and istanbul_df on df.Belediyeler and istanbul_df.District. Make it a inner join. Only add the second column of df to the end of join.

merged_df = pd.merge(istanbul_df, population, left_on='District', right_on='Belediyeler', how='inner')
merged_df.drop(columns=['Belediyeler'], inplace=True)
merged_df.rename(columns={'2019 yılı nüfusları': 'Population'}, inplace=True)
merged_df.drop(columns=['Province', 'PlateNumber','Province_Latitude','Province_Longitude'], inplace=True)
merged_df.head()
# Out:
#      District  District_Latitude  District_Longitude  Population
# 0      Adalar          40.867800           29.133100       15238
# 1  Arnavutköy          41.248259           28.681450      282488
# 2    Ataşehir          40.984749           29.106720      425094
# 3     Avcılar          40.980135           28.717547      448882
# 4    Bağcılar          41.044729           28.833714      745125

# %%
merged_df.sort_values(by='Population', ascending=False).head()
# Out:
#         District  District_Latitude  District_Longitude  Population
# 17      Esenyurt          41.048920           28.658117      954579
# 25  Küçükçekmece          40.996000           28.774800      792821
# 4       Bağcılar          41.044729           28.833714      745125
# 27        Pendik          40.877500           29.272500      711894
# 36      Ümraniye          41.027219           29.127459      710280

# %%
import numpy as np

# Given parameters
vehicle_ownership_rate = 0.25    # 25%
ev_penetration_rate = 0.02      # 2%
market_share = 0.3              # 20%
vehicles_per_station_capacity = 20  # One unit serves 20 cars

# Compute the number of EVs in each district
merged_df['Number_of_EVs'] = merged_df['Population'] * vehicle_ownership_rate * ev_penetration_rate

# Compute the number of EVs using our customer's stations
merged_df['EVs_using_customer_stations'] = merged_df['Number_of_EVs'] * market_share

# Compute the demand (number of capacity units needed) in each district
merged_df['Demand'] = merged_df['EVs_using_customer_stations'] / vehicles_per_station_capacity

# Round up the demand to the nearest integer, ensuring at least one unit of demand
merged_df['Demand'] = merged_df['Demand'].apply(lambda x: max(int(np.ceil(x)), 1))
merged_df=merged_df.drop(columns=["Number_of_EVs","EVs_using_customer_stations"])
# Display the DataFrame with the new normalized column
merged_df.head(5)
# Out:
#      District  District_Latitude  District_Longitude  Population  Demand
# 0      Adalar          40.867800           29.133100       15238       2
# 1  Arnavutköy          41.248259           28.681450      282488      22
# 2    Ataşehir          40.984749           29.106720      425094      32
# 3     Avcılar          40.980135           28.717547      448882      34
# 4    Bağcılar          41.044729           28.833714      745125      56

# %%
stations=pd.read_excel('borusan.xlsx')

# %%
stations=stations.iloc[:,3:9].drop(columns=['Nüfus','Mahalle'])
stations.columns=['Street','District','latitude','longitude']
stations.District=stations.District.str.replace('İ','I')
stations = stations[~stations['District'].isin(['ADALAR', 'ŞILE'])]
np.random.seed(42)
stations['Capacity'] = np.random.randint(5, 20, size=len(stations))
stations.head()
# Out:
#                  Street      District   latitude  longitude  Capacity
# 0      BAĞCILAR100. YIL      BAĞCILAR  41.063656  28.852570        11
# 1      ESENLER15 TEMMUZ       ESENLER  41.062042  28.877897         8
# 2  BÜYÜKÇEKMECE19 MAYIS  BÜYÜKÇEKMECE  41.022483  28.581827        17
# 3       KADIKÖY19 MAYIS       KADIKÖY  40.977008  29.089437        19
# 4         ŞIŞLI19 MAYIS         ŞIŞLI  41.059865  28.991444        15

# %%
stations.District.str.replace('İ','I').unique()
# Out:
# array(['BAĞCILAR', 'ESENLER', 'BÜYÜKÇEKMECE', 'KADIKÖY', 'ŞIŞLI',
#        'EYÜPSULTAN', 'SULTANGAZI', 'BEŞIKTAŞ', 'GÜNGÖREN', 'SANCAKTEPE',
#        'SULTANBEYLI', 'BEYKOZ', 'ÜSKÜDAR', 'ÜMRANIYE', 'BEYLIKDÜZÜ',
#        'ARNAVUTKÖY', 'PENDIK', 'ÇATALCA', 'ESENYURT', 'TUZLA', 'SILIVRI',
#        'FATIH', 'ÇEKMEKÖY', 'MALTEPE', 'BAŞAKŞEHIR', 'BAYRAMPAŞA',
#        'AVCILAR', 'BEYOĞLU', 'ATAŞEHIR', 'KÜÇÜKÇEKMECE', 'BAKIRKÖY',
#        'KARTAL', 'SARIYER', 'GAZIOSMANPAŞA', 'BAHÇELIEVLER',
#        'ZEYTINBURNU', 'KAĞITHANE'], dtype=object)

# %%
merged_df.District.str.upper().unique()
# Out:
# array(['ADALAR', 'ARNAVUTKÖY', 'ATAŞEHIR', 'AVCILAR', 'BAĞCILAR',
#        'BAHÇELIEVLER', 'BAKIRKÖY', 'BAŞAKŞEHIR', 'BAYRAMPAŞA', 'BEŞIKTAŞ',
#        'BEYKOZ', 'BEYLIKDÜZÜ', 'BEYOĞLU', 'BÜYÜKÇEKMECE', 'ÇATALCA',
#        'ÇEKMEKÖY', 'ESENLER', 'ESENYURT', 'EYÜPSULTAN', 'FATIH',
#        'GAZIOSMANPAŞA', 'GÜNGÖREN', 'KADIKÖY', 'KAĞITHANE', 'KARTAL',
#        'KÜÇÜKÇEKMECE', 'MALTEPE', 'PENDIK', 'SANCAKTEPE', 'SARIYER',
#        'SILIVRI', 'SULTANBEYLI', 'SULTANGAZI', 'ŞILE', 'ŞIŞLI', 'TUZLA',
#        'ÜMRANIYE', 'ÜSKÜDAR', 'ZEYTINBURNU'], dtype=object)

# %%
merged_df[['District','Demand']].head()
# Out:
#      District  Demand
# 0      Adalar       2
# 1  Arnavutköy      22
# 2    Ataşehir      32
# 3     Avcılar      34
# 4    Bağcılar      56

# %%
merged_df.Demand.sort_values(ascending=False)
# Out:
# 17    72
# 25    60
# 4     56
# 27    54
# 36    54
# 5     46
# 32    41
# 37    40
# 26    39
# 22    37
# 20    37
# 24    36
# 7     35
# 16    34
# 19    34
# 23    34
# 3     34
# 28    33
# 2     32
# 18    31
# 29    27
# 11    27
# 31    26
# 38    23
# 21    22
# 1     22
# 34    21
# 35    21
# 8     21
# 15    20
# 13    20
# 10    19
# 12    18
# 6     18
# 30    15
# 9     14
# 14     6
# 33     3
# 0      2
# Name: Demand, dtype: int64

# %%
import pulp
import numpy as np
import pandas as pd
from geopy.distance import geodesic

# Load district data
district_data=merged_df[merged_df.Demand>5].reset_index(drop=True)

# Extract district locations and demands
district_locations = district_data[['District_Latitude', 'District_Longitude']].values
district_demands = district_data['Demand'].values.astype(int)  # Ensure demands are integers
district_indices = district_data.index.values

# Generate 50 station locations evenly distributed
num_stations = len(stations)
#num_selected_stations = 50  # Increased from 25 to 30

# Generate stations
np.random.seed(42)  # For reproducibility
station_lats = stations.latitude
station_lons = stations.longitude
station_locations = list(zip(station_lats, station_lons))

# Assign capacities randomly between 5 and 30 (increase minimum capacity)
N_i = stations.Capacity.values


# Assign fixed costs
V = 100  # Variable cost per slot

# Fixed costs based on location
station_fixed_costs = []
for lat, lon in station_locations:
    distances = [geodesic((lat, lon), (d_lat, d_lon)).km for d_lat, d_lon in district_locations]
    nearest_district_idx = np.argmin(distances)
    population = district_data.loc[nearest_district_idx, 'Population']
    fixed_cost = population * 0.05  # Adjust coefficient as needed
    station_fixed_costs.append(fixed_cost)

# Total cost per station
station_total_costs = [station_fixed_costs[i] + V * N_i[i] for i in range(num_stations)]

# Distance threshold
theta = 5  # in kilometers

# Utilization rates
U_min = 0.1
U_max = 1.0

# Initialize the optimization problem
prob = pulp.LpProblem("EV_Charging_Stations_Optimization", pulp.LpMinimize)

# Decision variables
x = [pulp.LpVariable(f"x_{i}", cat='Binary') for i in range(num_stations)]
y = [[pulp.LpVariable(f"y_{i}_{j}", lowBound=0, cat='Integer')
    for j in range(len(district_data))]
    for i in range(num_stations)]

# Objective function
TotalCost = pulp.lpSum([station_total_costs[i] * x[i] for i in range(num_stations)])
prob += TotalCost

# Constraints

# 1. Station selection constraint
#prob += pulp.lpSum([x[i] for i in range(num_stations)]) == num_selected_stations, "Total_Stations_Selected"

# 2. Demand satisfaction constraints
for j in range(len(district_data)):
    prob += pulp.lpSum([y[i][j] for i in range(num_stations)]) == district_demands[j], f"Demand_Satisfaction_{j}"

# 3. Supply constraints
for i in range(num_stations):
    prob += pulp.lpSum([y[i][j] for j in range(len(district_data))]) <= N_i[i] * x[i], f"Supply_Limit_{i}"

# 4. Service distance constraint
for i in range(num_stations):
    for j in range(len(district_data)):
        distance = geodesic(station_locations[i], district_locations[j]).km
        if distance <= theta:
            s_ij = 1
        else:
            s_ij = 0
        # If s_ij is 0, y[i][j] must be 0
        prob += y[i][j] <= district_demands[j] * s_ij, f"Service_Distance_{i}_{j}"

# 5. Utilization balance constraints
for i in range(num_stations):
    min_utilization = int(U_min * N_i[i])
    max_utilization = int(U_max * N_i[i])
    prob += pulp.lpSum([y[i][j] for j in range(len(district_data))]) >= min_utilization * x[i], f"Min_Utilization_{i}"
    prob += pulp.lpSum([y[i][j] for j in range(len(district_data))]) <= max_utilization * x[i], f"Max_Utilization_{i}"

# Solve the problem
print('Started solving')

prob.solve(pulp.PULP_CBC_CMD(msg=True, timeLimit=600))

# Check solver status
status = pulp.LpStatus[prob.status]
print("Status:", status)

print(f"Optimal Total Cost: ${pulp.value(prob.objective):,.0f}\n")
selected_stations = []
for i in range(num_stations):
    if x[i].varValue == 1:
        selected_stations.append(i)
        station_capacity = N_i[i]
        total_supply = sum([y[i][j].varValue for j in range(len(district_data))])
        print(f"Station {i}:")
        print(f"  Location: {station_locations[i]}")
        print(f"  Capacity (Number of Slots): {station_capacity}")
        print(f"  Fixed Cost: {station_fixed_costs[i]:.2f}")
        print(f"  Variable Cost: {V * station_capacity}")
        print(f"  Total Cost: {station_total_costs[i]:.2f}")
        print(f"  Total Supply: {int(total_supply)}")
        if total_supply > station_capacity:
            print(f"  Warning: Total supply exceeds capacity!")
        supplied_districts = []
        for j in range(len(district_data)):
            supply = y[i][j].varValue
            if supply > 0:
                supplied_districts.append((district_data.loc[j, 'District'], int(supply)))
        print(f"  Supplies to Districts: {supplied_districts}\n")
# Verify that all districts' demands are met
for j in range(len(district_data)):
    total_supply = sum([y[i][j].varValue for i in range(num_stations)])
    print(f"District {district_data.loc[j, 'District']} Demand: {district_demands[j]}, Supplied: {int(total_supply)}")
# Out:
# Started solving
# Status: Optimal
# Optimal Total Cost: $1,363,639
#
# Station 3:
#   Location: (40.977008, 29.0894372)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 21254.70
#   Variable Cost: 1900
#   Total Cost: 23154.70
#   Total Supply: 19
#   Supplies to Districts: [('Kadıköy', 19)]
#
# Station 18:
#   Location: (41.2132529, 28.7039075)
#   Capacity (Number of Slots): 12
#   Fixed Cost: 14124.40
#   Variable Cost: 1200
#   Total Cost: 15324.40
#   Total Supply: 11
#   Supplies to Districts: [('Arnavutköy', 11)]
#
# Station 32:
#   Location: (40.9670161, 29.2303824)
#   Capacity (Number of Slots): 14
#   Fixed Cost: 16801.05
#   Variable Cost: 1400
#   Total Cost: 18201.05
#   Total Supply: 14
#   Supplies to Districts: [('Sancaktepe', 14)]
#
# Station 34:
#   Location: (41.0172962, 28.6944236)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 22444.10
#   Variable Cost: 1700
#   Total Cost: 24144.10
#   Total Supply: 17
#   Supplies to Districts: [('Avcılar', 1), ('Esenyurt', 16)]
#
# Station 48:
#   Location: (40.951875, 29.1016652)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 21254.70
#   Variable Cost: 1800
#   Total Cost: 23054.70
#   Total Supply: 18
#   Supplies to Districts: [('Maltepe', 18)]
#
# Station 74:
#   Location: (40.9908392, 29.1265531)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 21254.70
#   Variable Cost: 1900
#   Total Cost: 23154.70
#   Total Supply: 19
#   Supplies to Districts: [('Ümraniye', 19)]
#
# Station 86:
#   Location: (40.8672273, 29.3280673)
#   Capacity (Number of Slots): 12
#   Fixed Cost: 13370.00
#   Variable Cost: 1200
#   Total Cost: 14570.00
#   Total Supply: 12
#   Supplies to Districts: [('Pendik', 8), ('Tuzla', 4)]
#
# Station 108:
#   Location: (41.0320032, 28.9482931)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 11666.15
#   Variable Cost: 1800
#   Total Cost: 13466.15
#   Total Supply: 18
#   Supplies to Districts: [('Bayrampaşa', 18)]
#
# Station 111:
#   Location: (41.0590382, 29.0147694)
#   Capacity (Number of Slots): 13
#   Fixed Cost: 9132.45
#   Variable Cost: 1300
#   Total Cost: 10432.45
#   Total Supply: 13
#   Supplies to Districts: [('Beyoğlu', 2), ('Kağıthane', 6), ('Şişli', 5)]
#
# Station 117:
#   Location: (41.0741036, 28.8903557)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 24598.10
#   Variable Cost: 1900
#   Total Cost: 26498.10
#   Total Supply: 19
#   Supplies to Districts: [('Sultangazi', 19)]
#
# Station 122:
#   Location: (41.1060988, 28.7907747)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 23012.95
#   Variable Cost: 1600
#   Total Cost: 24612.95
#   Total Supply: 16
#   Supplies to Districts: [('Başakşehir', 16)]
#
# Station 127:
#   Location: (41.0790159, 29.0439589)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 9132.45
#   Variable Cost: 1700
#   Total Cost: 10832.45
#   Total Supply: 17
#   Supplies to Districts: [('Üsküdar', 17)]
#
# Station 128:
#   Location: (41.0289452, 28.9688617)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 11666.15
#   Variable Cost: 1900
#   Total Cost: 13566.15
#   Total Supply: 19
#   Supplies to Districts: [('Eyüpsultan', 19)]
#
# Station 136:
#   Location: (41.1343422, 29.090244)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 12413.00
#   Variable Cost: 1600
#   Total Cost: 14013.00
#   Total Supply: 16
#   Supplies to Districts: [('Beykoz', 16)]
#
# Station 155:
#   Location: (41.0088557, 28.647306)
#   Capacity (Number of Slots): 13
#   Fixed Cost: 17620.60
#   Variable Cost: 1300
#   Total Cost: 18920.60
#   Total Supply: 13
#   Supplies to Districts: [('Esenyurt', 13)]
#
# Station 175:
#   Location: (41.0171118, 28.8529333)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 14472.05
#   Variable Cost: 1800
#   Total Cost: 16272.05
#   Total Supply: 18
#   Supplies to Districts: [('Bağcılar', 18)]
#
# Station 180:
#   Location: (41.0169451, 28.6489243)
#   Capacity (Number of Slots): 11
#   Fixed Cost: 17620.60
#   Variable Cost: 1100
#   Total Cost: 18720.60
#   Total Supply: 11
#   Supplies to Districts: [('Esenyurt', 11)]
#
# Station 184:
#   Location: (41.0697432, 28.2612532)
#   Capacity (Number of Slots): 15
#   Fixed Cost: 9684.00
#   Variable Cost: 1500
#   Total Cost: 11184.00
#   Total Supply: 15
#   Supplies to Districts: [('Silivri', 15)]
#
# Station 193:
#   Location: (41.1486212, 29.0831591)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 12413.00
#   Variable Cost: 1900
#   Total Cost: 14313.00
#   Total Supply: 19
#   Supplies to Districts: [('Sarıyer', 19)]
#
# Station 217:
#   Location: (41.0267887, 28.8954257)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 14472.05
#   Variable Cost: 1800
#   Total Cost: 16272.05
#   Total Supply: 17
#   Supplies to Districts: [('Eyüpsultan', 11), ('Güngören', 6)]
#
# Station 222:
#   Location: (41.0043769, 28.826637)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 30552.95
#   Variable Cost: 1600
#   Total Cost: 32152.95
#   Total Supply: 16
#   Supplies to Districts: [('Küçükçekmece', 16)]
#
# Station 284:
#   Location: (41.2188627, 28.7028347)
#   Capacity (Number of Slots): 11
#   Fixed Cost: 14124.40
#   Variable Cost: 1100
#   Total Cost: 15224.40
#   Total Supply: 11
#   Supplies to Districts: [('Arnavutköy', 11)]
#
# Station 305:
#   Location: (41.141659, 28.4630541)
#   Capacity (Number of Slots): 9
#   Fixed Cost: 3685.90
#   Variable Cost: 900
#   Total Cost: 4585.90
#   Total Supply: 6
#   Supplies to Districts: [('Çatalca', 6)]
#
# Station 310:
#   Location: (41.0016533, 28.8329435)
#   Capacity (Number of Slots): 15
#   Fixed Cost: 30552.95
#   Variable Cost: 1500
#   Total Cost: 32052.95
#   Total Supply: 15
#   Supplies to Districts: [('Güngören', 3), ('Küçükçekmece', 12)]
#
# Station 311:
#   Location: (41.0387523, 28.883188)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 13736.75
#   Variable Cost: 1900
#   Total Cost: 15636.75
#   Total Supply: 19
#   Supplies to Districts: [('Bağcılar', 19)]
#
# Station 345:
#   Location: (40.98106, 28.7357032)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 22444.10
#   Variable Cost: 1800
#   Total Cost: 24244.10
#   Total Supply: 18
#   Supplies to Districts: [('Avcılar', 5), ('Küçükçekmece', 13)]
#
# Station 362:
#   Location: (41.0105887, 28.6655614)
#   Capacity (Number of Slots): 11
#   Fixed Cost: 17620.60
#   Variable Cost: 1100
#   Total Cost: 18720.60
#   Total Supply: 11
#   Supplies to Districts: [('Esenyurt', 11)]
#
# Station 453:
#   Location: (41.0809627, 28.8821623)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 24598.10
#   Variable Cost: 1700
#   Total Cost: 26298.10
#   Total Supply: 17
#   Supplies to Districts: [('Sultangazi', 17)]
#
# Station 457:
#   Location: (41.0852087, 28.8986424)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 24598.10
#   Variable Cost: 1900
#   Total Cost: 26498.10
#   Total Supply: 19
#   Supplies to Districts: [('Esenler', 14), ('Sultangazi', 5)]
#
# Station 462:
#   Location: (41.054732, 28.9034132)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 13736.75
#   Variable Cost: 1900
#   Total Cost: 15636.75
#   Total Supply: 19
#   Supplies to Districts: [('Gaziosmanpaşa', 19)]
#
# Station 471:
#   Location: (40.9836971, 29.1431977)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 21254.70
#   Variable Cost: 1900
#   Total Cost: 23154.70
#   Total Supply: 19
#   Supplies to Districts: [('Maltepe', 19)]
#
# Station 479:
#   Location: (40.9881118, 28.9093458)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 14678.70
#   Variable Cost: 1900
#   Total Cost: 16578.70
#   Total Supply: 19
#   Supplies to Districts: [('Güngören', 13), ('Zeytinburnu', 6)]
#
# Station 514:
#   Location: (40.9142051, 29.3002734)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 35594.70
#   Variable Cost: 1800
#   Total Cost: 37394.70
#   Total Supply: 18
#   Supplies to Districts: [('Pendik', 18)]
#
# Station 515:
#   Location: (41.0623719, 29.03454)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 9132.45
#   Variable Cost: 1600
#   Total Cost: 10732.45
#   Total Supply: 16
#   Supplies to Districts: [('Üsküdar', 16)]
#
# Station 523:
#   Location: (40.9803353, 29.1130781)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 21254.70
#   Variable Cost: 1900
#   Total Cost: 23154.70
#   Total Supply: 16
#   Supplies to Districts: [('Ataşehir', 15), ('Kadıköy', 1)]
#
# Station 528:
#   Location: (41.0627178, 29.0194489)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 9132.45
#   Variable Cost: 1900
#   Total Cost: 11032.45
#   Total Supply: 17
#   Supplies to Districts: [('Kağıthane', 10), ('Üsküdar', 7)]
#
# Station 529:
#   Location: (41.0815723, 29.0169502)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 9132.45
#   Variable Cost: 1800
#   Total Cost: 10932.45
#   Total Supply: 18
#   Supplies to Districts: [('Kağıthane', 18)]
#
# Station 539:
#   Location: (40.9818388, 28.6718702)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 17620.60
#   Variable Cost: 1900
#   Total Cost: 19520.60
#   Total Supply: 19
#   Supplies to Districts: [('Avcılar', 19)]
#
# Station 542:
#   Location: (41.0520844, 29.0203549)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 9132.45
#   Variable Cost: 1600
#   Total Cost: 10732.45
#   Total Supply: 16
#   Supplies to Districts: [('Beyoğlu', 16)]
#
# Station 548:
#   Location: (40.9681066, 29.2676872)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 16801.05
#   Variable Cost: 1600
#   Total Cost: 18401.05
#   Total Supply: 16
#   Supplies to Districts: [('Sancaktepe', 6), ('Sultanbeyli', 10)]
#
# Station 551:
#   Location: (41.0138079, 28.6667966)
#   Capacity (Number of Slots): 11
#   Fixed Cost: 17620.60
#   Variable Cost: 1100
#   Total Cost: 18720.60
#   Total Supply: 11
#   Supplies to Districts: [('Esenyurt', 11)]
#
# Station 556:
#   Location: (41.0395441, 28.8804397)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 13736.75
#   Variable Cost: 1800
#   Total Cost: 15536.75
#   Total Supply: 18
#   Supplies to Districts: [('Bağcılar', 1), ('Gaziosmanpaşa', 17)]
#
# Station 570:
#   Location: (40.9858884, 29.1532413)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 21254.70
#   Variable Cost: 1900
#   Total Cost: 23154.70
#   Total Supply: 19
#   Supplies to Districts: [('Ataşehir', 17), ('Maltepe', 2)]
#
# Station 579:
#   Location: (41.0358974, 28.8848756)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 14472.05
#   Variable Cost: 1800
#   Total Cost: 16272.05
#   Total Supply: 18
#   Supplies to Districts: [('Bağcılar', 18)]
#
# Station 612:
#   Location: (41.0408946, 29.2656098)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 13225.40
#   Variable Cost: 1700
#   Total Cost: 14925.40
#   Total Supply: 17
#   Supplies to Districts: [('Çekmeköy', 17)]
#
# Station 618:
#   Location: (40.8660896, 29.2894246)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 35594.70
#   Variable Cost: 1800
#   Total Cost: 37394.70
#   Total Supply: 18
#   Supplies to Districts: [('Pendik', 18)]
#
# Station 619:
#   Location: (40.8941812, 29.3569093)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 13370.00
#   Variable Cost: 1800
#   Total Cost: 15170.00
#   Total Supply: 17
#   Supplies to Districts: [('Tuzla', 17)]
#
# Station 620:
#   Location: (40.9061849, 29.1614584)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 23533.80
#   Variable Cost: 1800
#   Total Cost: 25333.80
#   Total Supply: 18
#   Supplies to Districts: [('Kartal', 18)]
#
# Station 627:
#   Location: (41.1454717, 29.0873267)
#   Capacity (Number of Slots): 11
#   Fixed Cost: 12413.00
#   Variable Cost: 1100
#   Total Cost: 13513.00
#   Total Supply: 11
#   Supplies to Districts: [('Beykoz', 3), ('Sarıyer', 8)]
#
# Station 674:
#   Location: (41.08497655, 29.0567656239769)
#   Capacity (Number of Slots): 14
#   Fixed Cost: 9132.45
#   Variable Cost: 1400
#   Total Cost: 10532.45
#   Total Supply: 14
#   Supplies to Districts: [('Beşiktaş', 14)]
#
# Station 678:
#   Location: (41.0081748, 28.6976834)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 22444.10
#   Variable Cost: 1700
#   Total Cost: 24144.10
#   Total Supply: 17
#   Supplies to Districts: [('Avcılar', 9), ('Beylikdüzü', 8)]
#
# Station 680:
#   Location: (40.9706957, 28.6486713728992)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 17620.60
#   Variable Cost: 1900
#   Total Cost: 19520.60
#   Total Supply: 19
#   Supplies to Districts: [('Beylikdüzü', 19)]
#
# Station 683:
#   Location: (40.9777116, 28.8792335)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 11461.95
#   Variable Cost: 1700
#   Total Cost: 13161.95
#   Total Supply: 17
#   Supplies to Districts: [('Bahçelievler', 17)]
#
# Station 709:
#   Location: (40.9970063, 28.5365245)
#   Capacity (Number of Slots): 13
#   Fixed Cost: 12705.15
#   Variable Cost: 1300
#   Total Cost: 14005.15
#   Total Supply: 13
#   Supplies to Districts: [('Büyükçekmece', 13)]
#
# Station 727:
#   Location: (41.0368412, 28.9723566)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 11666.15
#   Variable Cost: 1800
#   Total Cost: 13466.15
#   Total Supply: 18
#   Supplies to Districts: [('Fatih', 18)]
#
# Station 756:
#   Location: (41.031185, 29.2311306)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 13225.40
#   Variable Cost: 1600
#   Total Cost: 14825.40
#   Total Supply: 16
#   Supplies to Districts: [('Çekmeköy', 3), ('Sancaktepe', 13)]
#
# Station 785:
#   Location: (41.0305283, 28.5494574)
#   Capacity (Number of Slots): 7
#   Fixed Cost: 12705.15
#   Variable Cost: 700
#   Total Cost: 13405.15
#   Total Supply: 7
#   Supplies to Districts: [('Büyükçekmece', 7)]
#
# Station 791:
#   Location: (41.0344293, 28.9070683)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 13736.75
#   Variable Cost: 1900
#   Total Cost: 15636.75
#   Total Supply: 19
#   Supplies to Districts: [('Esenler', 19)]
#
# Station 796:
#   Location: (41.0339473, 28.9715307)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 11666.15
#   Variable Cost: 1600
#   Total Cost: 13266.15
#   Total Supply: 16
#   Supplies to Districts: [('Fatih', 16)]
#
# Station 799:
#   Location: (40.9204738, 29.2246565)
#   Capacity (Number of Slots): 10
#   Fixed Cost: 23533.80
#   Variable Cost: 1000
#   Total Cost: 24533.80
#   Total Supply: 10
#   Supplies to Districts: [('Kartal', 10)]
#
# Station 801:
#   Location: (40.8919905, 29.2205714)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 23533.80
#   Variable Cost: 1800
#   Total Cost: 25333.80
#   Total Supply: 18
#   Supplies to Districts: [('Kartal', 8), ('Pendik', 10)]
#
# Station 811:
#   Location: (41.0352866, 28.8925614)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 13736.75
#   Variable Cost: 1700
#   Total Cost: 15436.75
#   Total Supply: 17
#   Supplies to Districts: [('Bahçelievler', 11), ('Bayrampaşa', 3), ('Esenler', 1), ('Eyüpsultan', 1), ('Gaziosmanpaşa', 1)]
#
# Station 829:
#   Location: (40.9926219, 28.773674)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 39641.05
#   Variable Cost: 1900
#   Total Cost: 41541.05
#   Total Supply: 19
#   Supplies to Districts: [('Küçükçekmece', 19)]
#
# Station 840:
#   Location: (40.9795971, 28.8795876)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 11461.95
#   Variable Cost: 1800
#   Total Cost: 13261.95
#   Total Supply: 18
#   Supplies to Districts: [('Bahçelievler', 18)]
#
# Station 842:
#   Location: (40.9887283, 29.0906789)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 21254.70
#   Variable Cost: 1700
#   Total Cost: 22954.70
#   Total Supply: 17
#   Supplies to Districts: [('Kadıköy', 17)]
#
# Station 843:
#   Location: (40.9939446, 29.140645)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 21254.70
#   Variable Cost: 1700
#   Total Cost: 22954.70
#   Total Supply: 17
#   Supplies to Districts: [('Ümraniye', 17)]
#
# Station 845:
#   Location: (40.9312919, 29.3043382)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 16801.05
#   Variable Cost: 1600
#   Total Cost: 18401.05
#   Total Supply: 16
#   Supplies to Districts: [('Sultanbeyli', 16)]
#
# Station 846:
#   Location: (41.0087952, 29.0985116)
#   Capacity (Number of Slots): 18
#   Fixed Cost: 21254.70
#   Variable Cost: 1800
#   Total Cost: 23054.70
#   Total Supply: 18
#   Supplies to Districts: [('Ümraniye', 18)]
#
# Station 852:
#   Location: (40.9589829, 28.8225574)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 11461.95
#   Variable Cost: 1900
#   Total Cost: 13361.95
#   Total Supply: 18
#   Supplies to Districts: [('Bakırköy', 18)]
#
# Station 858:
#   Location: (41.0479707, 29.0145236)
#   Capacity (Number of Slots): 16
#   Fixed Cost: 9132.45
#   Variable Cost: 1600
#   Total Cost: 10732.45
#   Total Supply: 16
#   Supplies to Districts: [('Şişli', 16)]
#
# Station 869:
#   Location: (41.0176797, 28.6855692)
#   Capacity (Number of Slots): 10
#   Fixed Cost: 17620.60
#   Variable Cost: 1000
#   Total Cost: 18620.60
#   Total Supply: 10
#   Supplies to Districts: [('Esenyurt', 10)]
#
# Station 874:
#   Location: (40.9789622, 28.8724028)
#   Capacity (Number of Slots): 17
#   Fixed Cost: 11461.95
#   Variable Cost: 1700
#   Total Cost: 13161.95
#   Total Supply: 17
#   Supplies to Districts: [('Zeytinburnu', 17)]
#
# Station 875:
#   Location: (41.0751841, 28.7879081)
#   Capacity (Number of Slots): 19
#   Fixed Cost: 23012.95
#   Variable Cost: 1900
#   Total Cost: 24912.95
#   Total Supply: 19
#   Supplies to Districts: [('Başakşehir', 19)]
#
# District Arnavutköy Demand: 22, Supplied: 22
# District Ataşehir Demand: 32, Supplied: 32
# District Avcılar Demand: 34, Supplied: 34
# District Bağcılar Demand: 56, Supplied: 56
# District Bahçelievler Demand: 46, Supplied: 46
# District Bakırköy Demand: 18, Supplied: 18
# District Başakşehir Demand: 35, Supplied: 35
# District Bayrampaşa Demand: 21, Supplied: 21
# District Beşiktaş Demand: 14, Supplied: 14
# District Beykoz Demand: 19, Supplied: 19
# District Beylikdüzü Demand: 27, Supplied: 27
# District Beyoğlu Demand: 18, Supplied: 18
# District Büyükçekmece Demand: 20, Supplied: 20
# District Çatalca Demand: 6, Supplied: 6
# District Çekmeköy Demand: 20, Supplied: 20
# District Esenler Demand: 34, Supplied: 34
# District Esenyurt Demand: 72, Supplied: 72
# District Eyüpsultan Demand: 31, Supplied: 31
# District Fatih Demand: 34, Supplied: 34
# District Gaziosmanpaşa Demand: 37, Supplied: 37
# District Güngören Demand: 22, Supplied: 22
# District Kadıköy Demand: 37, Supplied: 37
# District Kağıthane Demand: 34, Supplied: 34
# District Kartal Demand: 36, Supplied: 36
# District Küçükçekmece Demand: 60, Supplied: 60
# District Maltepe Demand: 39, Supplied: 39
# District Pendik Demand: 54, Supplied: 54
# District Sancaktepe Demand: 33, Supplied: 33
# District Sarıyer Demand: 27, Supplied: 27
# District Silivri Demand: 15, Supplied: 15
# District Sultanbeyli Demand: 26, Supplied: 26
# District Sultangazi Demand: 41, Supplied: 41
# District Şişli Demand: 21, Supplied: 21
# District Tuzla Demand: 21, Supplied: 21
# District Ümraniye Demand: 54, Supplied: 54
# District Üsküdar Demand: 40, Supplied: 40
# District Zeytinburnu Demand: 23, Supplied: 23

# %%
# Filter the stations DataFrame based on selected_stations list
stations_filtered = stations[stations.index.isin(selected_stations)].reset_index(drop=True)

# Export the filtered DataFrame to a CSV file
stations_filtered.to_excel('filtered_stations.xlsx', index=False)

# %%
stations[stations.index.isin(selected_stations)]
# Out:
#                             Street      District   latitude  longitude  \
# 3                  KADIKÖY19 MAYIS       KADIKÖY  40.977008  29.089437
# 44                  FATIHALI KUŞÇU         FATIH  41.020696  28.948447
# 47             EYÜPSULTANALIBEYKÖY    EYÜPSULTAN  41.077257  28.946893
# 65              BEŞIKTAŞARNAVUTKÖY      BEŞIKTAŞ  41.067177  29.043271
# 74   BAKIRKÖYATAKÖY 2. 5. 6. KISIM      BAKIRKÖY  40.977617  28.857788
# 80             BÜYÜKÇEKMECEATATÜRK  BÜYÜKÇEKMECE  41.012264  28.600402
# 96                  BAĞCILARBAĞLAR      BAĞCILAR  41.022887  28.824829
# 105             PENDIKBAHÇELIEVLER        PENDIK  40.883911  29.235379
# 117                  PENDIKBALLICA        PENDIK  40.990429  29.401439
# 128                   ÇATALCABAŞAK       ÇATALCA  41.332951  28.445322
# 139           ZEYTINBURNUBEŞTELSIZ   ZEYTINBURNU  40.999487  28.904502
# 174                ÇATALCACELEPKÖY       ÇATALCA  41.365407  28.499759
# 181               BAKIRKÖYCEVIZLIK      BAKIRKÖY  40.978507  28.875534
# 186         BAHÇELIEVLERCUMHURIYET  BAHÇELIEVLER  41.017112  28.852933
# 187               BEYKOZCUMHURIYET        BEYKOZ  41.129065  29.260744
# 193         KÜÇÜKÇEKMECECUMHURIYET  KÜÇÜKÇEKMECE  40.996729  28.771205
# 204               BEYKOZÇAMLIBAHÇE        BEYKOZ  41.148621  29.083159
# 257              BEŞIKTAŞDIKILITAŞ      BEŞIKTAŞ  41.055431  29.004849
# 264             ÜMRANIYEDUMLUPINAR      ÜMRANIYE  41.049046  29.094224
# 269            BÜYÜKÇEKMECEEKINOBA  BÜYÜKÇEKMECE  41.010183  28.542241
# 302             TUZLAEVLIYA ÇELEBI         TUZLA  40.842592  29.298457
# 311                  ESENYURTFATIH      ESENYURT  41.029897  28.674647
# 326              ÇATALCAFERHATPAŞA       ÇATALCA  41.141659  28.463054
# 401                ÇATALCAHALLAÇLI       ÇATALCA  41.318171  28.097558
# 462            BAYRAMPAŞAISMETPAŞA    BAYRAMPAŞA  41.041653  28.906621
# 471                 ÇATALCAKABAKÇA       ÇATALCA  41.228460  28.369591
# 479           BÜYÜKÇEKMECEKAMILOBA  BÜYÜKÇEKMECE  41.046125  28.432120
# 483              BEYOĞLUKAPTANPAŞA       BEYOĞLU  41.042277  28.963838
# 514         ESENLERKAZIM KARABEKIR       ESENLER  41.046408  28.873158
# 518          ZEYTINBURNUKAZLIÇEŞME   ZEYTINBURNU  40.988112  28.909346
# 523                   ESENLERKEMER       ESENLER  41.052626  28.876571
# 539                 SARIYERKOCATAŞ       SARIYER  41.168930  29.035260
# 566           ÜSKÜDARKÜÇÜK ÇAMLICA       ÜSKÜDAR  41.015111  29.064057
# 570         ATAŞEHIRKÜÇÜKBAKKALKÖY      ATAŞEHIR  40.980335  29.113078
# 589              ARNAVUTKÖYMAVIGÖL    ARNAVUTKÖY  41.204218  28.764377
# 600     KAĞITHANEMEHMET AKIF ERSOY     KAĞITHANE  41.059300  28.956404
# 612                KAĞITHANEMERKEZ     KAĞITHANE  41.079396  28.969239
# 649             BEYOĞLUMÜEYYETZADE       BEYOĞLU  41.026338  28.974776
# 758                  SILIVRISEYMEN       SILIVRI  41.156450  28.170454
# 762          EYÜPSULTANSILAHTARAĞA    EYÜPSULTAN  41.061323  28.940364
# 782       SULTANGAZISULTANÇIFTLIĞI    SULTANGAZI  41.100394  28.860903
# 791               ZEYTINBURNUSÜMER   ZEYTINBURNU  40.986405  28.895472
# 801              BAKIRKÖYŞENLIKKÖY      BAKIRKÖY  40.981149  28.795145
# 829                 BEYKOZTOKATKÖY        BEYKOZ  41.151273  29.090294
#
#      Capacity
# 3          19
# 44         15
# 47         16
# 65         11
# 74         14
# 80         16
# 96         10
# 105        16
# 117        16
# 128        13
# 139        11
# 174        12
# 181         7
# 186        18
# 187         7
# 193        18
# 204        19
# 257        18
# 264        11
# 269        18
# 302         6
# 311         6
# 326         9
# 401         8
# 462        16
# 471         5
# 479        17
# 483         7
# 514        12
# 518        19
# 523        15
# 539        11
# 566        16
# 570        19
# 589        15
# 600         8
# 612        16
# 649        19
# 758         6
# 762        12
# 782        11
# 791        11
# 801        10
# 829        15
